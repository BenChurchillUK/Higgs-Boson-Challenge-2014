# %% [markdown]
# ## Investigating Higgs Boson ML Challenge (2014) Features

# %% [markdown]
# The following features are defined in CERN's opendata records. https://opendata.cern.ch/record/328
#
# - DER_mass_MMC
# - DER_mass_transverse_met_lep
# - DER_mass_vis
# - DER_pt_h
# - DER_deltaeta_jet_jet
# - DER_mass_jet_jet
# - DER_prodeta_jet_jet
# - DER_deltar_tau_lep
# - DER_pt_tot
# - DER_sum_pt
# - DER_pt_ratio_lep_tau
# - DER_met_phi_centrality
# - DER_lep_eta_centrality
# - PRI_tau_pt
# - PRI_tau_eta
# - PRI_tau_phi
# - PRI_lep_pt
# - PRI_lep_phi
# - PRI_met
# - PRI_met_phi
# - PRI_met_sumet
# - PRI_jet_num
# - PRI_jet_leading_pt
# - PRI_jet_leading_eta
# - PRI_jet_leading_phi
# - PRI_jet_subleading_pt
# - PRI_jet_subleading_eta
# - PRI_jet_subleading_phi
# - PRI_jet_all_pt

# %% [markdown]
# ### Libraries, Modules and Data

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import sys

root = Path().resolve()
while not (root/"src").exists():
    root = root.parent
sys.path.append(str(root))

from src.data_processing import pull_data
from src.feature_investigation import signal_processing_histogram

df = pull_data()

# %% [markdown]
# #### Estimated Mass 'm<sub>H</sub>'
# The following section will explore the relevance of estimated mass of the boson candidate. As the histogram shows, there's a lot of overlap between the signals and noise, suggesting this feature wouldn't have much impact on seperating candidates.
#
# Column Name: DER_mass_MMC

# %%
signal_processing_histogram(df, "DER_mass_MMC", "Estimated Mass")

# %% [markdown]
# #### Transverse Mass
# Column Name: DER_mass_transverse_met_lep

# %%
signal_processing_histogram(df, "DER_mass_transverse_met_lep", "Transverse Mass")

# %% [markdown]
# #### Invariant Mass
# Column Name: DER_mass_vis

# %%
signal_processing_histogram(df, "DER_mass_vis", "Invariant Mass")

# %% [markdown]
# #### Modulus of the Vector Sum of the Transverse Momentum
# Column Name: DER_pt_h

# %%
signal_processing_histogram(df, "DER_pt_h", "Modulus of the Vector Sum of the Transverse Momentum")

# %% [markdown]
# #### Absolute Value of the Pseudorapidity Separation between Two Jets
# Column Name: DER_deltaeta_jet_jet

# %%
signal_processing_histogram(df, "DER_deltaeta_jet_jet", "Absolute Value of the Pseudorapidity Separation between Two Jets")

# %% [markdown]
# #### Invariant Mass of Two Jets
# Column Name: DER_mass_jet_jet

# %%
signal_processing_histogram(df, "DER_mass_jet_jet", "Invariant Mass of Two Jets")

# %% [markdown]
# #### Product of the Pseudorapidities of Two Jets
# Column Name: DER_prodeta_jet_jet

# %%
signal_processing_histogram(df, "DER_prodeta_jet_jet", "Product of the Pseudorapidities of Two Jets")

# %% [markdown]
# #### R Separation
# Column Name: DER_deltar_tau_lep

# %%
signal_processing_histogram(df, "DER_deltar_tau_lep", "R Separation")

# %% [markdown]
# #### Modulus of the Vector Sum of the Missing Transverse Momenta
# Column Name: DER_pt_tot

# %%
signal_processing_histogram(df, "DER_pt_tot", "Modulus of the Vector Sum of the Missing Transverse Momenta")

# %% [markdown]
# #### Sum of the Moduli of the Transverse Momenta
# DER_sum_pt

# %%
signal_processing_histogram(df, "DER_sum_pt", "Sum of the Moduli of the Transverse Momenta")

# %% [markdown]
# #### Ratio of the Transverse Momenta
# DER_pt_ratio_lep_tau

# %%
signal_processing_histogram(df, "DER_pt_ratio_lep_tau", "Ratio of the Transverse Momenta")

# %% [markdown]
# #### Centrality of the Azimuthal Angle of the Missing Transverse Energy Vector
# Column Name: DER_met_phi_centrality

# %%
signal_processing_histogram(df, "DER_met_phi_centrality", "Centrality of the Azimuthal Angle of the Missing Transverse Energy Vector")

# %% [markdown]
# #### Centrality of the Pseudorapidity of the Lepton
# Column Name: DER_lep_eta_centrality

# %%
signal_processing_histogram(df, "DER_lep_eta_centrality", "Centrality of the Pseudorapidity of the Lepton")

# %% [markdown]
# #### Transverse Momentum of the Hadronic Tau
# Column Name: PRI_tau_pt

# %%
signal_processing_histogram(df, "PRI_tau_pt", "Transvere Momentum")

# %% [markdown]
# #### Pseudorapidity of the Hadronic Tau
# Column Name: PRI_tau_eta

# %%
signal_processing_histogram(df, "PRI_tau_eta", "Pseudorapidity of the Hadronic Tau")

# %% [markdown]
# #### Azimuth Angle of the Hadronic Tau
# Column Name: PRI_tau_phi

# %%
signal_processing_histogram(df, "PRI_tau_phi", "Azimuth Angle of the Hadronic Tau")

# %% [markdown]
# #### Transverse Momentum of the Lepton
# PRI_lep_pt

# %%
signal_processing_histogram(df, "PRI_lep_pt", "Transverse Momentum of the Lepton")

# %% [markdown]
# #### Pseudorapidity of the Lepton
# Column Name: PRI_lep_phi

# %%
signal_processing_histogram(df, "PRI_lep_phi", "Pseudorapidity of the Lepton")

# %% [markdown]
# #### Missing Transverse Energy
# Column Name: PRI_met

# %%
signal_processing_histogram(df, "PRI_met", "Missing Transverse Energy")

# %% [markdown]
# #### Azimuth Angle of the Missing Transverse Energy
# Column Name: PRI_met_phi

# %%
signal_processing_histogram(df, "PRI_met_phi", "Azimuth Angle of the Missing Transverse Energy")

# %% [markdown]
# #### Total Transverse Energy in the Detctor
# PRI_met_sumet

# %%
signal_processing_histogram(df, "PRI_met_sumet", "Total Transverse Energy in the Detctor")

# %% [markdown]
# #### Number of Jets
# PRI_jet_num

# %%
signal_processing_histogram(df, "PRI_jet_num", "Number of Jets")

# %% [markdown]
# #### Transverse Momentum of the Leading Jet
# PRI_jet_leading_pt

# %%
signal_processing_histogram(df, "PRI_jet_leading_pt", "Transverse Momentum of the Leading Jet")

# %% [markdown]
# #### Pseudorapidity of the Leading Jet
# PRI_jet_leading_eta

# %%
signal_processing_histogram(df, "PRI_jet_leading_eta", "Pseudorapidity of the Leading Jet")

# %% [markdown]
# #### Azimuth Angle of the Leading Jet
# Column Name: PRI_jet_leading_phi

# %%
signal_processing_histogram(df, "PRI_jet_leading_phi", "Azimuth Angle of the Leading Jet")

# %% [markdown]
# #### Transverse Momentum of the Subleading Jet
# Column Name: PRI_jet_subleading_pt

# %%
signal_processing_histogram(df, "PRI_jet_subleading_pt", "Transverse Momentum of the Subleading Jet")

# %% [markdown]
# #### Pseudorapidity of the Subleading Jet
# PRI_jet_subleading_eta

# %%
signal_processing_histogram(df, "PRI_jet_subleading_eta", "Pseudorapidity of the Subleading Jet")

# %% [markdown]
# #### Azimuth Angle of the Subleading Jet
# PRI_jet_subleading_phi

# %%
signal_processing_histogram(df, "PRI_jet_subleading_phi", "Azimuth Angle of the Subleading Jet")

# %% [markdown]
# #### Scalar Sum of the Transverse Momentum
# PRI_jet_all_pt

# %%
signal_processing_histogram(df, "PRI_jet_all_pt", "Scalar Sum of the Transverse Momentum")
